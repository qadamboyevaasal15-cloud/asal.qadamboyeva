# %% [markdown]
# # Funksiyalar

# %%
def kutb_olish():
    print("Salom, xush kelibsiz")

# %%
kutb_olish()
# Out:
# Salom, xush kelibsiz

# %% [markdown]
# # Parametrli funksiyalar

# %%
def kutb_olish_2(a):
    print(f"Salom {a}, xush kelibsiz")

# %%
kutb_olish_2("asal")
# Out:
# Salom asal, xush kelibsiz

# %% [markdown]
# * ** / // - + %

# %%
def togri_tortburchak_yuzi(a, b):
    print(a*b)

# %%
togri_tortburchak_yuzi(4, 9)
# Out:
# 36

# %%
# to'g'ri burchakli uchburchakning yuzini topadigan funksiya yarating. (0.5*a*b)

# %%
def yuzi(a, b):
    return 0.5*a*b

# %%
s = yuzi(3, 8)
s + 10
# Out:
# 22.0

# %%
# defult parametr berish
def kutb_olish_2(a="Xonim"):
    print(f"salom {a}, xush kelibsiz")

# %%
kutb_olish_2("Ali")
# Out:
# salom Ali, xush kelibsiz

# %%
def daraja(asos, darajasi=2):
    return asos ** darajasi

# %%
daraja(10, -4)
# Out:
# 0.0001

# %%
daraja(25)
# Out:
# 625

# %%
numbers = [4, 8, 7, -3, 6, 88, 11, 0.008, 546]

def tekshir(a):
    return max(a), min(a)

tekshir(numbers)
# Out:
# (546, -3)

# %%
def ortacha(b):
    return sum(b)/len(b)

# %%
ortacha(numbers)
# Out:
# 74.11200000000001

# %%
def tekshir(a):
    maximum = max(a)
    minimum = min(a)
    avarage = sum(a)/len(a)

    return f"""{a} to'plamidagi maximum son bu {maximum},
    minimum son bu {minimum},
    O'rtacha qiymat bu {avarage}"""

# %%
print(tekshir(numbers))
# Out:
# [4, 8, 7, -3, 6, 88, 11, 0.008, 546] to'plamidagi maximum son bu 546,
#     minimum son bu -3,
#     O'rtacha qiymat bu 74.11200000000001

# %% [markdown]
# # *args**kwargs
# * *args - pasitional argument
# * **kvargs - keyword argument

# %%
def yigindisi(a, b, c):
    return a+b+c
yigindisi(1,2, 2)
# Out:
# 5

# %%
def qoshish(*b):
    return sum(b)

# %%
qoshish(4,8,6,45,67)
# Out:
# 130

# %% [markdown]
# # Mashq
# 1. Istalgan sonni kavadrat darajaga kotarsin.
# 2. Istalgan sonni kvadrat ildiz chiqarsin.

# %%
def kvadrat(*a):
    return [i**2 for i in a]
kvadrat(4, 5, 6, 9, 11)
# Out:
# [16, 25, 36, 81, 121]

# %%
def kvadrat(*a):
    return [i**2 for i in a]
kvadrat(4, 5, 6, 9, 11)
kvadrat_ildiz(16, 64, 625, 46)
# Out:
# [4.0, 8.0, 25.0, 6.782329983125268]

# %%
def kvadrat_ildiz_input(*a):
    return [i**2 for i in a]
son = [float(i) for i in input("Son kiriting").split(",")]
kvadrat_ildiz_input(*son)

# %% [markdown]
# # lambda funksiya

# %%
son_kvadrati = lambda a: a**2

# %%
son_kvadrati(4)
